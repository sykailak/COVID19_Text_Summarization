# %% [markdown]
# # part1: pre-processing-text-for-GPT2-fine-tuning.ipynb

# %% [markdown]
# ##Load Packages

# %%
#%cd '/content/drive/My Drive/Colab Notebooks/GPT-2/summarization_preprocessing'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import timeit

import torch
print(torch.__version__,' pytorch version')
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

# !pip install transformers==2.6.0
# Out:
# 1.7.0+cu101  pytorch version
# Requirement already satisfied: transformers==2.6.0 in /usr/local/lib/python3.6/dist-packages (2.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (1.19.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (0.1.95)
# Requirement already satisfied: tokenizers==0.5.2 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (0.5.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (0.0.43)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (4.41.1)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (1.16.63)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (3.0.12)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.6.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.6.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.6.0) (1.0.0)
# Requirement already satisfied: botocore<1.20.0,>=1.19.63 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.6.0) (1.19.63)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.6.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.6.0) (0.3.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.20.0,>=1.19.63->boto3->transformers==2.6.0) (2.8.1)

# %%
import transformers
print(transformers.__version__,' make sure transformers version is 2.6.0')
from transformers import GPT2Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('distilgpt2')
special_tokens = {'bos_token':'<|startoftext|>','eos_token':'<|endoftext|>','pad_token':'<pad>','additional_special_tokens':['<|keyword|>','<|summarize|>']}
tokenizer.add_special_tokens(special_tokens)
print(len(tokenizer), 'total length of vocab')
print(tokenizer.bos_token_id, 'bos_token')
print(tokenizer.eos_token_id, 'eos_token')
print(tokenizer.pad_token_id, 'pad_token')  #token for <pad>, len of all tokens in the tokenizer
print(tokenizer.additional_special_tokens_ids[0], 'keyword_token') #token for <|keyword|>
print(tokenizer.additional_special_tokens_ids[1], 'summary_token') #token for <|summarize|>
# Out:
# 2.6.0  make sure transformers version is 2.6.0
# 50261 total length of vocab
# 50257 bos_token
# 50256 eos_token
# 50258 pad_token
# 50259 keyword_token
# 50260 summary_token

# %% [markdown]
# ##Load the dataset (before processing)¶
# reset index before running pre-processing so the columns will match up.

# %%
frame_dev = pd.read_csv('/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021/COVID19_train_data.csv',index_col=0)

# %%
frame_dev = frame_dev.reset_index()
frame_dev.head(5)
# Out:
#    index  ...                                    keyword_POS_str
# 0  29933  ...  Abstract order assess immunotherapeutic potent...
# 1  11345  ...  Coronaviruses CoVs bat origin have caused pand...
# 2  17525  ...  Hypertrofie van het lymfoïde weefsel de nasofa...
# 3  20795  ...  Abstract rabbit patients other species analyzi...
# 4  23210  ...  cyclophilin inhibitors cyclosporin A CsA Alisp...
#
# [5 rows x 8 columns]

# %% [markdown]
# ##Helper Function

# %%
def load_words(df, num, with_title = False):
  """import dataframe with number of what sample to choose,
  return a keyword (together with title or not) as strings
  and abstract (gold label for summarization).
  and 3 distractors. all as a tuple of 5 strings"""
  arr_distract = np.random.randint(len(df), size=3)
  keyword = df['keyword_POS_str'][num]
  if with_title:
    title = df['title'][num]
    keyword = title + keyword
  abstract = df['abstract'][num]
  distract1 = df['abstract'][arr_distract[0]]
  distract2 = df['abstract'][arr_distract[1]]
  distract3 = df['abstract'][arr_distract[2]]

  return (keyword,abstract,distract1,distract2,distract3)

# %%
def write_input_ids(word_batch,max_len=1024):#,max_len=1024):
  """
  tokenize the input
  then return list of input tokens
  """
  key, abstract, dis1,dis2,dis3 = word_batch

  if len(key)>max_len:
      key = key[:max_len]
  if len(abstract)>max_len:
      abstract = abstract[:max_len]
  if len(dis1)>max_len:
      dis1 = dis1[:max_len]
  if len(dis2)>max_len:
      dis2 = dis2[:max_len]
  if len(dis3)>max_len:
      dis3 = dis3[:max_len]
      
  input_true = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ abstract + ' <|endoftext|>',max_length = tokenizer.max_len)
  assert 50260 in input_true
  input_dis1 = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ dis1 + ' <|endoftext|>',max_length = tokenizer.max_len)
  input_dis2 = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ dis2 + ' <|endoftext|>',max_length = tokenizer.max_len)
  input_dis3 = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ dis3 + ' <|endoftext|>',max_length = tokenizer.max_len)
  
  if max_len == None:
    max_len = max(len(input_true),len(input_dis1),len(input_dis2),len(input_dis3))

  for i in [input_true,input_dis1,input_dis2,input_dis3]:
    while len(i) < max_len:
      i.append(tokenizer.pad_token_id)
  list_input_token = [input_true,input_dis1,input_dis2,input_dis3]
  return list_input_token

# %%
def write_token_type_labels(list_input_ids,max_len=1024):
  '''
  creating segment tokens
  (either keyword, summary, or padding segment)

  list_input_ids: [input_true,input_dis1,input_dis2,input_dis3]
  '''
  list_segment = []
  for item in list_input_ids:
    try:
      item.index(tokenizer.eos_token_id)
    except:
      item[-1] = tokenizer.eos_token_id
    num_seg_a = item.index(tokenizer.additional_special_tokens_ids[1]) + 1
    end_index = item.index(tokenizer.eos_token_id)
    num_seg_b = end_index - num_seg_a + 1
    num_pad = max_len - end_index - 1
    segment_ids = [tokenizer.additional_special_tokens_ids[0]]*num_seg_a + [tokenizer.additional_special_tokens_ids[1]]*num_seg_b + [tokenizer.pad_token_id]*num_pad
    list_segment.append(segment_ids)
  return list_segment

# %%
def write_lm_labels(list_input_ids,list_type_labels):
  '''
  write the label for the lm head 
  (only on the correct pair; i.e. the 0th element of the list; 
  else where is masked with [-100] token to prevent the model from 
  computing cross entropy loss).

  '''
  list_lm_label = []
  is_true_label = True
  for input_tokens,segments in zip(list_input_ids,list_type_labels): #by each summary
    if is_true_label:
      is_true_label = False
      temp_list = []
      for token,segment in zip(input_tokens,segments):
        if segment == tokenizer.additional_special_tokens_ids[1]:#only abstract!!
          temp_list.append(token)
        else:
          temp_list.append(-100) #if not abstract (i.e. keyword, padding)
      list_lm_label.append(temp_list)
    else:
      temp_list = [-100]*len(input_tokens) #if not true abstract, put [-100]
      list_lm_label.append(temp_list)
  return list_lm_label

# %%
def write_last_token(list_input_ids):
  '''
  return the last token before padding (i.e. the <|endoftext|>) 
  (this is recognized by the mc head for the multiple choice loss)
  '''
  list_mc_token = []
  for item in list_input_ids:
    list_mc_token.append(item.index(tokenizer.eos_token_id))
  return list_mc_token

# %%
def write_mc_label():
  '''
  return [1,0,0,0] because the correct pair is always the 0th element of the list
  '''
  return [1,0,0,0]

# %%
def shuffle_batch(list_input_ids,list_type_labels,list_last_tokens,list_lm_labels,list_mc_labels):
  '''
  shuffle the tuple. After this the correct pair can be any element. return numpy array
  '''
  array_input_token = np.array(list_input_ids)
  array_segment = np.array(list_type_labels)
  array_mc_token = np.array(list_last_tokens)
  array_lm_label = np.array(list_lm_labels)
  array_mc_label = np.array(list_mc_labels)

  randomize = np.arange(4)
  np.random.shuffle(randomize)

  array_input_token = array_input_token[randomize]
  array_segment = array_segment[randomize]
  array_mc_token = array_mc_token[randomize]
  array_lm_label = array_lm_label[randomize]
  array_mc_label = array_mc_label[randomize]

  return (array_input_token,array_segment,array_mc_token,array_lm_label,array_mc_label)

# %%
def write_torch_tensor(np_batch):
  '''
  create a tensor object from the numpy array
  '''
  torch_input_token = torch.tensor(np_batch[0], dtype=torch.long).unsqueeze(0)
  torch_segment = torch.tensor(np_batch[1],dtype=torch.long).unsqueeze(0)
  torch_mc_token = torch.tensor(np_batch[2],dtype=torch.long).unsqueeze(0)
  torch_lm_label = torch.tensor(np_batch[3],dtype=torch.long).unsqueeze(0)
  torch_mc_label = torch.tensor([np.argmax(np_batch[4])],dtype=torch.long).unsqueeze(0)
  return (torch_input_token,torch_segment,torch_mc_token,torch_lm_label,torch_mc_label)

# %% [markdown]
# ##write a big function
#
# execute all 8 helper functions
#
# concatenate the temporary tensor object every 1000 items.
#
# This is done for the sake of time efficiency. concat tensor on a very long tensor takes a bit of time.

# %%
def execute_all_function(df):
  exist_temp_tensor = False
  exist_big_tensor = False
  start = timeit.default_timer()
  for num in range(len(df)): #32146
    word_tuple = load_words(df, num) #(keyword,abstract,distract1,distract2,distract3)
    if type(word_tuple[0]) != str or type(word_tuple[1]) != str:
      # continue returns the control to the beginning of the loop
      continue
    
    list_input_ids = write_input_ids(word_tuple) #output: [input_true,input_dis1,input_dis2,input_dis3]
    list_type_labels = write_token_type_labels(list_input_ids) #[input_true segment_ids, input_dis1 segment_ids, input_dis2 segment_ids, input_dis3 segment_ids]
    list_lm_labels = write_lm_labels(list_input_ids,list_type_labels) #[input_true lm_ids, input_dis1 lm_ids, input_dis2 lm_ids, input_dis3 lm_ids]
    
    # for each keyword+summary, get the index of <eos> token
    list_last_tokens = write_last_token(list_input_ids)
    list_mc_labels = write_mc_label() #return [1,0,0,0]

    np_tuple = shuffle_batch(list_input_ids,list_type_labels,list_last_tokens,list_lm_labels,list_mc_labels)
    tensor_tuple = write_torch_tensor(np_tuple)
    
    if not exist_temp_tensor:
      temp_0 = tensor_tuple[0]
      temp_1 = tensor_tuple[1]
      temp_2 = tensor_tuple[2]
      temp_3 = tensor_tuple[3]
      temp_4 = tensor_tuple[4]
      exist_temp_tensor = True
    elif exist_temp_tensor:
      temp_0 = torch.cat((temp_0,tensor_tuple[0]),0)
      temp_1 = torch.cat((temp_1,tensor_tuple[1]),0)
      temp_2 = torch.cat((temp_2,tensor_tuple[2]),0)
      temp_3 = torch.cat((temp_3,tensor_tuple[3]),0)
      temp_4 = torch.cat((temp_4,tensor_tuple[4]),0)

    if num % 1000 == 0:
      if not exist_big_tensor:
        big_first_tensor = temp_0
        big_second_tensor = temp_1
        big_third_tensor = temp_2
        big_fourth_tensor = temp_3
        big_fifth_tensor = temp_4
        exist_temp_tensor = False
        exist_big_tensor = True
        del temp_0,temp_1,temp_2,temp_3,temp_4
      else:
        big_first_tensor = torch.cat((big_first_tensor,temp_0),0)
        big_second_tensor = torch.cat((big_second_tensor,temp_1),0)
        big_third_tensor = torch.cat((big_third_tensor,temp_2),0)
        big_fourth_tensor = torch.cat((big_fourth_tensor,temp_3),0)
        big_fifth_tensor = torch.cat((big_fifth_tensor,temp_4),0)
        exist_temp_tensor = False
        del temp_0,temp_1,temp_2,temp_3,temp_4
      
      stop = timeit.default_timer()
      print('iterations ',num,' takes ', stop - start,' sec')
      start = timeit.default_timer()
  
  big_first_tensor = torch.cat((big_first_tensor,temp_0),0)
  big_second_tensor = torch.cat((big_second_tensor,temp_1),0)
  big_third_tensor = torch.cat((big_third_tensor,temp_2),0)
  big_fourth_tensor = torch.cat((big_fourth_tensor,temp_3),0)
  big_fifth_tensor = torch.cat((big_fifth_tensor,temp_4),0)
  return big_first_tensor, big_second_tensor, big_third_tensor,big_fourth_tensor,big_fifth_tensor

# %%
tensor_1,tensor_2,tensor_3,tensor_4,tensor_5 = execute_all_function(frame_dev)
# Out:
# iterations  0  takes  0.06450268200001119  sec
# iterations  1000  takes  20.634436464999965  sec
# iterations  2000  takes  19.52589998000002  sec
# iterations  3000  takes  19.31977676500003  sec
# iterations  4000  takes  19.328844215000004  sec
# iterations  5000  takes  19.185199529000045  sec
# iterations  6000  takes  19.19430839800009  sec
# iterations  7000  takes  19.275529386000017  sec
# iterations  8000  takes  19.015346636000004  sec
# iterations  9000  takes  19.10094117199992  sec
# iterations  10000  takes  19.225099813000043  sec
# iterations  11000  takes  19.095336440999972  sec
# iterations  12000  takes  19.081980534999957  sec
# iterations  13000  takes  19.247761438999987  sec
# iterations  14000  takes  19.104330066999978  sec
# iterations  15000  takes  19.28937768700007  sec
# iterations  16000  takes  19.363567287000023  sec
# iterations  17000  takes  19.430583260999924  sec
# iterations  18000  takes  19.314859392000017  sec
# iterations  19000  takes  19.471804277000047  sec
# iterations  20000  takes  19.502318918000014  sec
# iterations  21000  takes  19.394892867000067  sec
# iterations  22000  takes  19.45961197500003  sec
# iterations  23000  takes  19.445594720999907  sec
# iterations  24000  takes  19.35159616699991  sec
# iterations  25000  takes  19.446239087000095  sec
# iterations  26000  takes  19.520128453999973  sec
# iterations  27000  takes  19.564169523000032  sec
# iterations  28000  takes  19.740301054000042  sec
# iterations  29000  takes  19.658207018999974  sec
# iterations  30000  takes  19.61603555599993  sec
# iterations  31000  takes  19.620005945000116  sec
# iterations  32000  takes  19.82234655100001  sec

# %%
# create a tensor dataset object
tensor_dataset = TensorDataset(tensor_1,tensor_2,tensor_3,tensor_4,tensor_5)

# %%
# save the tensor object to load later when training
torch.save(tensor_dataset, 'torch_devFile_1_May07_2020.pt')

# %% [markdown]
# ##check your result by printing statement
# Make sure the labels are all correct and lined up

# %%
tensor_5.numpy() #list_mc_labels
# Out:
# array([[3],
#        [0],
#        [1],
#        ...,
#        [3],
#        [2],
#        [3]])

# %%
item = 1515
print(tensor_1[item])
print(tensor_2[item])
print(tensor_3[item])
print(tensor_4[item])
print(tensor_5[item])
# Out:
# tensor([[50257, 46631, 23674,  ..., 50258, 50258, 50258],
#         [50257, 46631, 23674,  ..., 50258, 50258, 50258],
#         [50257, 46631, 23674,  ..., 50258, 50258, 50258],
#         [50257, 46631, 23674,  ..., 50258, 50258, 50258]])
# tensor([[50259, 50259, 50259,  ..., 50258, 50258, 50258],
#         [50259, 50259, 50259,  ..., 50258, 50258, 50258],
#         [50259, 50259, 50259,  ..., 50258, 50258, 50258],
#         [50259, 50259, 50259,  ..., 50258, 50258, 50258]])
# tensor([395, 328, 377, 356])
# tensor([[-100, -100, -100,  ..., -100, -100, -100],
#         [-100, -100, -100,  ..., -100, -100, -100],
#         [-100, -100, -100,  ..., -100, -100, -100],
#         [-100, -100, -100,  ..., -100, -100, -100]])
# tensor([1])

# %%
print('{:>2}{:>10}{:>10}{:>10}{:>10}{:>20}{:>10}{:>20}{:>10}'.format('count','input','decoded input','input','decoded input','input','decoded input','input','decoded input'))
count = 0
for i,j,k,m in zip(tensor_1[item][1],tensor_1[item][2],tensor_2[item][2],tensor_4[item][2]):
  i = int(i)
  j = int(j)
  k = int(k)
  m = int(m)
  if i == -100:
    decode_i = 'masked'
  else:
    decode_i = tokenizer.decode(i)
  if j == -100:
    decode_j = 'masked'
  else:
    decode_j = tokenizer.decode(j)
  if k == -100:
    decode_k = 'masked'
  else:
    decode_k = tokenizer.decode(k)
  if m == -100:
    decode_m = 'masked'
  else:
    decode_m = tokenizer.decode(m)
  #print(i,j)
  print('{:>2}{:>10}{:>10}{:>10}{:>10}{:>20}{:>10}{:>20}{:>10}'.format(count,i,decode_i,j,decode_j,k,decode_k,m,decode_m))
  count += 1
# Out:
# count     inputdecoded input     inputdecoded input               inputdecoded input               inputdecoded input
#  0     50257<|startoftext|>     50257<|startoftext|>               50259<|keyword|>                -100    masked
#  1     46631     Influ     46631     Influ               50259<|keyword|>                -100    masked
#  2     23674      enza     23674      enza               50259<|keyword|>                -100    masked
#  3       317         A       317         A               50259<|keyword|>                -100    masked
#  4     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
#  5       389       are       389       are               50259<|keyword|>                -100    masked
#  6     12077   amongst     12077   amongst               50259<|keyword|>                -100    masked
#  7      9389 challenging      9389 challenging               50259<|keyword|>                -100    masked
#  8     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
#  9     16180  threaten     16180  threaten               50259<|keyword|>                -100    masked
# 10      1692     human      1692     human               50259<|keyword|>                -100    masked
# 11      5044    animal      5044    animal               50259<|keyword|>                -100    masked
# 12      1535    health      1535    health               50259<|keyword|>                -100    masked
# 13     46631     Influ     46631     Influ               50259<|keyword|>                -100    masked
# 14     23674      enza     23674      enza               50259<|keyword|>                -100    masked
# 15     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
# 16       389       are       389       are               50259<|keyword|>                -100    masked
# 17      3748    unique      3748    unique               50259<|keyword|>                -100    masked
# 18       867      many       867      many               50259<|keyword|>                -100    masked
# 19      2842      ways      2842      ways               50259<|keyword|>                -100    masked
# 20       389       are       389       are               50259<|keyword|>                -100    masked
# 21      3748    unique      3748    unique               50259<|keyword|>                -100    masked
# 22      9573 diversity      9573 diversity               50259<|keyword|>                -100    masked
# 23      2583      host      2583      host               50259<|keyword|>                -100    masked
# 24      4693   species      4693   species               50259<|keyword|>                -100    masked
# 25      7580    infect      7580    infect               50259<|keyword|>                -100    masked
# 26      3407  includes      3407  includes               50259<|keyword|>                -100    masked
# 27      1660     water      1660     water               50259<|keyword|>                -100    masked
# 28        69         f        69         f               50259<|keyword|>                -100    masked
# 29      4883       owl      4883       owl               50259<|keyword|>                -100    masked
# 30      2656  original      2656  original               50259<|keyword|>                -100    masked
# 31     22115 reservoir     22115 reservoir               50259<|keyword|>                -100    masked
# 32     35609 terrestrial     35609 terrestrial               50259<|keyword|>                -100    masked
# 33     37115   aquatic     37115   aquatic               50259<|keyword|>                -100    masked
# 34     34101   poultry     34101   poultry               50259<|keyword|>                -100    masked
# 35      1509        sw      1509        sw               50259<|keyword|>                -100    masked
# 36       500       ine       500       ine               50259<|keyword|>                -100    masked
# 37      5384    humans      5384    humans               50259<|keyword|>                -100    masked
# 38     14260    horses     14260    horses               50259<|keyword|>                -100    masked
# 39      3290       dog      3290       dog               50259<|keyword|>                -100    masked
# 40     11875      cats     11875      cats               50259<|keyword|>                -100    masked
# 41     24635    whales     24635    whales               50259<|keyword|>                -100    masked
# 42     29718     seals     29718     seals               50259<|keyword|>                -100    masked
# 43      1811   several      1811   several               50259<|keyword|>                -100    masked
# 44       584     other       584     other               50259<|keyword|>                -100    masked
# 45     46177 mammalian     46177 mammalian               50259<|keyword|>                -100    masked
# 46      4693   species      4693   species               50259<|keyword|>                -100    masked
# 47       389       are       389       are               50259<|keyword|>                -100    masked
# 48      3748    unique      3748    unique               50259<|keyword|>                -100    masked
# 49      5339  capacity      5339  capacity               50259<|keyword|>                -100    masked
# 50     18101    evolve     18101    evolve               50259<|keyword|>                -100    masked
# 51      6068     adapt      6068     adapt               50259<|keyword|>                -100    masked
# 52      1708 following      1708 following               50259<|keyword|>                -100    masked
# 53     12538  crossing     12538  crossing               50259<|keyword|>                -100    masked
# 54      4693   species      4693   species               50259<|keyword|>                -100    masked
# 55     13054   barrier     13054   barrier               50259<|keyword|>                -100    masked
# 56      1502     order      1502     order               50259<|keyword|>                -100    masked
# 57     24340 replicate     24340 replicate               50259<|keyword|>                -100    masked
# 58      4104    spread      4104    spread               50259<|keyword|>                -100    masked
# 59       584     other       584     other               50259<|keyword|>                -100    masked
# 60      3925 individuals      3925 individuals               50259<|keyword|>                -100    masked
# 61       649       new       649       new               50259<|keyword|>                -100    masked
# 62      4693   species      4693   species               50259<|keyword|>                -100    masked
# 63       389       are       389       are               50259<|keyword|>                -100    masked
# 64      3748    unique      3748    unique               50259<|keyword|>                -100    masked
# 65      8373 frequency      8373 frequency               50259<|keyword|>                -100    masked
# 66       987     inter       987     inter               50259<|keyword|>                -100    masked
# 67        12         -        12         -               50259<|keyword|>                -100    masked
# 68     35448   species     35448   species               50259<|keyword|>                -100    masked
# 69     11478 transmission     11478 transmission               50259<|keyword|>                -100    masked
# 70      2995    events      2995    events               50259<|keyword|>                -100    masked
# 71      3051     occur      3051     occur               50259<|keyword|>                -100    masked
# 72      6948 consequences      6948 consequences               50259<|keyword|>                -100    masked
# 73      5337     novel      5337     novel               50259<|keyword|>                -100    masked
# 74     29491 influenza     29491 influenza               50259<|keyword|>                -100    masked
# 75      9471     virus      9471     virus               50259<|keyword|>                -100    masked
# 76     14022    strain     14022    strain               50259<|keyword|>                -100    masked
# 77     41492     naïve     41492     naïve               50259<|keyword|>                -100    masked
# 78      3265 population      3265 population               50259<|keyword|>                -100    masked
# 79       307        be       307        be               50259<|keyword|>                -100    masked
# 80     14101 devastating     14101 devastating               50259<|keyword|>                -100    masked
# 81      2761  problems      2761  problems               50259<|keyword|>                -100    masked
# 82     29491 influenza     29491 influenza               50259<|keyword|>                -100    masked
# 83     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
# 84      1944   present      1944   present               50259<|keyword|>                -100    masked
# 85      1692     human      1692     human               50259<|keyword|>                -100    masked
# 86      5044    animal      5044    animal               50259<|keyword|>                -100    masked
# 87      1535    health      1535    health               50259<|keyword|>                -100    masked
# 88       389       are       389       are               50259<|keyword|>                -100    masked
# 89      6409  numerous      6409  numerous               50259<|keyword|>                -100    masked
# 90      1672   example      1672   example               50259<|keyword|>                -100    masked
# 91     29491 influenza     29491 influenza               50259<|keyword|>                -100    masked
# 92     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
# 93      5384    humans      5384    humans               50259<|keyword|>                -100    masked
# 94      2380 represent      2380 represent               50259<|keyword|>                -100    masked
# 95      1688     major      1688     major               50259<|keyword|>                -100    masked
# 96      3034  economic      3034  economic               50259<|keyword|>                -100    masked
# 97      4369   disease      4369   disease               50259<|keyword|>                -100    masked
# 98     10538    burden     10538    burden               50259<|keyword|>                -100    masked
# 99     14590    whilst     14590    whilst               50259<|keyword|>                -100    masked
# 100     34101   poultry     34101   poultry               50259<|keyword|>                -100    masked
# 101      2831  industry      2831  industry               50259<|keyword|>                -100    masked
# 102       468       has       468       has               50259<|keyword|>                -100    masked
# 103      6989  suffered      6989  suffered               50259<|keyword|>                -100    masked
# 104     41197  colossal     41197  colossal               50259<|keyword|>                -100    masked
# 105      2465    damage      2465    damage               50259<|keyword|>                -100    masked
# 106      2233       due      2233       due               50259<|keyword|>                -100    masked
# 107      5100  repeated      5100  repeated               50259<|keyword|>                -100    masked
# 108     35198 outbreaks     35198 outbreaks               50259<|keyword|>                -100    masked
# 109      3108      path      3108      path               50259<|keyword|>                -100    masked
# 110     15147    ogenic     15147    ogenic               50259<|keyword|>                -100    masked
# 111      1196        av      1196        av               50259<|keyword|>                -100    masked
# 112       666       ian       666       ian               50259<|keyword|>                -100    masked
# 113     29491 influenza     29491 influenza               50259<|keyword|>                -100    masked
# 114     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
# 115      2423    review      2423    review               50259<|keyword|>                -100    masked
# 116     12031      aims     12031      aims               50259<|keyword|>                -100    masked
# 117      2148   provide      2148   provide               50259<|keyword|>                -100    masked
# 118      9815 comprehensive      9815 comprehensive               50259<|keyword|>                -100    masked
# 119     16700  overview     16700  overview               50259<|keyword|>                -100    masked
# 120     29491 influenza     29491 influenza               50259<|keyword|>                -100    masked
# 121       317         A       317         A               50259<|keyword|>                -100    masked
# 122     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
# 123     39543  shedding     39543  shedding               50259<|keyword|>                -100    masked
# 124      1657     light      1657     light               50259<|keyword|>                -100    masked
# 125       987     inter       987     inter               50259<|keyword|>                -100    masked
# 126     35448   species     35448   species               50259<|keyword|>                -100    masked
# 127      9471     virus      9471     virus               50259<|keyword|>                -100    masked
# 128     11478 transmission     11478 transmission               50259<|keyword|>                -100    masked
# 129     15676    summar     15676    summar               50259<|keyword|>                -100    masked
# 130      1710     ising      1710     ising               50259<|keyword|>                -100    masked
# 131      1459   current      1459   current               50259<|keyword|>                -100    masked
# 132      3725 knowledge      3725 knowledge               50259<|keyword|>                -100    masked
# 133      5115 regarding      5115 regarding               50259<|keyword|>                -100    masked
# 134     29491 influenza     29491 influenza               50259<|keyword|>                -100    masked
# 135     20547   viruses     20547   viruses               50259<|keyword|>                -100    masked
# 136      6068     adapt      6068     adapt               50259<|keyword|>                -100    masked
# 137       649       new       649       new               50259<|keyword|>                -100    masked
# 138      2583      host      2583      host               50259<|keyword|>                -100    masked
# 139     50260<|summarize|>     50260<|summarize|>               50259<|keyword|>                -100    masked
# 140     46631     Influ     16310       Vir               50260<|summarize|>                -100    masked
# 141     23674      enza       282        al               50260<|summarize|>                -100    masked
# 142       317         A     46246       ful               50260<|summarize|>                -100    masked
# 143     20547   viruses      1084       min               50260<|summarize|>                -100    masked
# 144       389       are       415       ant               50260<|summarize|>                -100    masked
# 145     12077   amongst     37439 hepatitis               50260<|summarize|>                -100    masked
# 146       262       the       357         (               50260<|summarize|>                -100    masked
# 147       749      most     44602        FH               50260<|summarize|>                -100    masked
# 148      9389 challenging         8         )               50260<|summarize|>                -100    masked
# 149     20547   viruses       318        is               50260<|summarize|>                -100    masked
# 150       326      that       257         a               50260<|summarize|>                -100    masked
# 151     16180  threaten      6049    severe               50260<|summarize|>                -100    masked
# 152      1111      both      4369   disease               50260<|summarize|>                -100    masked
# 153      1692     human       351      with               50260<|summarize|>                -100    masked
# 154       290       and      1029      high               50260<|summarize|>                -100    masked
# 155      5044    animal     12430 mortality               50260<|summarize|>                -100    masked
# 156      1535    health      7186 resulting               50260<|summarize|>                -100    masked
# 157        13         .       422      from               50260<|summarize|>                -100    masked
# 158     46631     Influ     13181 excessive               50260<|summarize|>                -100    masked
# 159     23674      enza     20881 inflammation               50260<|summarize|>                -100    masked
# 160       317         A       287        in               50260<|summarize|>                -100    masked
# 161     20547   viruses       262       the               50260<|summarize|>                -100    masked
# 162       389       are     14112  infected               50260<|summarize|>                -100    masked
# 163      3748    unique     14383     liver               50260<|summarize|>                -100    masked
# 164       287        in        13         .               50260<|summarize|>                -100    masked
# 165       867      many     21234  Clinical               50260<|summarize|>                -100    masked
# 166      2842      ways     19901 interventions               50260<|summarize|>                -100    masked
# 167        13         .       423      have               50260<|summarize|>                -100    masked
# 168     41039   Firstly       587      been               50260<|summarize|>                -100    masked
# 169        11         ,     30904 inefficient               50260<|summarize|>                -100    masked
# 170       484      they      2233       due               50260<|summarize|>                -100    masked
# 171       389       are       284        to               50260<|summarize|>                -100    masked
# 172      3748    unique       262       the               50260<|summarize|>                -100    masked
# 173       287        in      3092      lack               50260<|summarize|>                -100    masked
# 174       262       the       286        of               50260<|summarize|>                -100    masked
# 175      9573 diversity      3725 knowledge               50260<|summarize|>                -100    masked
# 176       286        of       329       for               50260<|summarize|>                -100    masked
# 177      2583      host     23760 inflammatory               50260<|summarize|>                -100    masked
# 178      4693   species      3108      path               50260<|summarize|>                -100    masked
# 179       326      that     25908  ogenesis               50260<|summarize|>                -100    masked
# 180       484      they       287        in               50260<|summarize|>                -100    masked
# 181      7580    infect       262       the               50260<|summarize|>                -100    masked
# 182        13         .      9471     virus               50260<|summarize|>                -100    masked
# 183       770      This        12         -               50260<|summarize|>                -100    masked
# 184      3407  includes     27816    infect               50260<|summarize|>                -100    masked
# 185      1660     water       276        ed               50260<|summarize|>                -100    masked
# 186        69         f     14383     liver               50260<|summarize|>                -100    masked
# 187      4883       owl        13         .               50260<|summarize|>                -100    masked
# 188       357         (       775        We               50260<|summarize|>                -100    masked
# 189      1169       the       905      show               50260<|summarize|>                -100    masked
# 190      2656  original       326      that               50260<|summarize|>                -100    masked
# 191     22115 reservoir      4295      wild               50260<|summarize|>                -100    masked
# 192       828        ),        12         -               50260<|summarize|>                -100    masked
# 193     35609 terrestrial      4906      type               50260<|summarize|>                -100    masked
# 194       290       and     10693      mice               50260<|summarize|>                -100    masked
# 195     37115   aquatic     14112  infected               50260<|summarize|>                -100    masked
# 196     34101   poultry       351      with               50260<|summarize|>                -100    masked
# 197        11         ,      4636       mur               50260<|summarize|>                -100    masked
# 198      1509        sw       500       ine               50260<|summarize|>                -100    masked
# 199       500       ine     37439 hepatitis               50260<|summarize|>                -100    masked
# 200        11         ,      9471     virus               50260<|summarize|>                -100    masked
# 201      5384    humans     14022    strain               50260<|summarize|>                -100    masked
# 202        11         ,        12         -               50260<|summarize|>                -100    masked
# 203     14260    horses        18         3               50260<|summarize|>                -100    masked
# 204        11         ,       357         (               50260<|summarize|>                -100    masked
# 205      3290       dog     36208        MH               50260<|summarize|>                -100    masked
# 206        11         ,        53         V               50260<|summarize|>                -100    masked
# 207     11875      cats        12         -               50260<|summarize|>                -100    masked
# 208        11         ,        18         3               50260<|summarize|>                -100    masked
# 209     24635    whales       828        ),               50260<|summarize|>                -100    masked
# 210        11         ,       257         a               50260<|summarize|>                -100    masked
# 211     29718     seals      2746     model               50260<|summarize|>                -100    masked
# 212       290       and       329       for               50260<|summarize|>                -100    masked
# 213      1811   several     14416     viral               50260<|summarize|>                -100    masked
# 214       584     other       376         F               50260<|summarize|>                -100    masked
# 215     46177 mammalian        39         H               50260<|summarize|>                -100    masked
# 216      4693   species        11         ,               50260<|summarize|>                -100    masked
# 217        13         .     10561  manifest               50260<|summarize|>                -100    masked
# 218     34276  Secondly       351      with               50260<|summarize|>                -100    masked
# 219        11         ,      6049    severe               50260<|summarize|>                -100    masked
# 220       484      they      4369   disease               50260<|summarize|>                -100    masked
# 221       389       are       290       and               50260<|summarize|>                -100    masked
# 222      3748    unique      1029      high               50260<|summarize|>                -100    masked
# 223       287        in     12430 mortality               50260<|summarize|>                -100    masked
# 224       511     their       287        in               50260<|summarize|>                -100    masked
# 225      5339  capacity      8112 association               50260<|summarize|>                -100    masked
# 226       284        to       351      with               50260<|summarize|>                -100    masked
# 227     18101    evolve       257         a               50260<|summarize|>                -100    masked
# 228       290       and      2383 significant               50260<|summarize|>                -100    masked
# 229      6068     adapt     22910 elevation               50260<|summarize|>                -100    masked
# 230        11         ,       287        in               50260<|summarize|>                -100    masked
# 231      1708 following     14639        IL               50260<|summarize|>                -100    masked
# 232     12538  crossing        12         -               50260<|summarize|>                -100    masked
# 233       262       the        16         1               50260<|summarize|>                -100    masked
# 234      4693   species     26638         β               50260<|summarize|>                -100    masked
# 235     13054   barrier      5408 expression               50260<|summarize|>                -100    masked
# 236        11         ,       287        in               50260<|summarize|>                -100    masked
# 237       287        in       262       the               50260<|summarize|>                -100    masked
# 238      1502     order     20502     serum               50260<|summarize|>                -100    masked
# 239       284        to       290       and               50260<|summarize|>                -100    masked
# 240     24340 replicate     14383     liver               50260<|summarize|>                -100    masked
# 241       290       and        13         .               50260<|summarize|>                -100    masked
# 242      4104    spread     28016   Whereas               50260<|summarize|>                -100    masked
# 243       284        to        11         ,               50260<|summarize|>                -100    masked
# 244       584     other       262       the               50260<|summarize|>                -100    masked
# 245      3925 individuals     14416     viral               50260<|summarize|>                -100    masked
# 246      1626    within     10280 infection               50260<|summarize|>                -100    masked
# 247       262       the       287        in               50260<|summarize|>                -100    masked
# 248       649       new     14639        IL               50260<|summarize|>                -100    masked
# 249      4693   species        12         -               50260<|summarize|>                -100    masked
# 250        13         .        16         1               50260<|summarize|>                -100    masked
# 251      9461   Finally     26638         β               50260<|summarize|>                -100    masked
# 252        11         ,     17408  receptor               50260<|summarize|>                -100    masked
# 253       484      they        12         -               50260<|summarize|>                -100    masked
# 254       389       are        40         I               50260<|summarize|>                -100    masked
# 255      3748    unique     40043 deficient               50260<|summarize|>                -100    masked
# 256       287        in       357         (               50260<|summarize|>                -100    masked
# 257       262       the      4146        IL               50260<|summarize|>                -100    masked
# 258      8373 frequency        12         -               50260<|summarize|>                -100    masked
# 259       286        of        16         1               50260<|summarize|>                -100    masked
# 260       987     inter        49         R               50260<|summarize|>                -100    masked
# 261        12         -        16         1               50260<|summarize|>                -100    masked
# 262     35448   species     13841        (-               50260<|summarize|>                -100    masked
# 263     11478 transmission     16327        /-               50260<|summarize|>                -100    masked
# 264      2995    events      4008        ))               50260<|summarize|>                -100    masked
# 265       326      that       393        or               50260<|summarize|>                -100    masked
# 266      3051     occur     14639        IL               50260<|summarize|>                -100    masked
# 267        13         .        12         -               50260<|summarize|>                -100    masked
# 268      9676    Indeed        16         1               50260<|summarize|>                -100    masked
# 269        11         ,        49         R               50260<|summarize|>                -100    masked
# 270       262       the     34667 antagonist               50260<|summarize|>                -100    masked
# 271      6948 consequences       357         (               50260<|summarize|>                -100    masked
# 272       286        of      4146        IL               50260<|summarize|>                -100    masked
# 273      5337     novel        12         -               50260<|summarize|>                -100    masked
# 274     29491 influenza        16         1               50260<|summarize|>                -100    masked
# 275      9471     virus     21762        Ra               50260<|summarize|>                -100    masked
# 276     14022    strain         8         )               50260<|summarize|>                -100    masked
# 277       287        in      5716   treated               50260<|summarize|>                -100    masked
# 278       281        an     10693      mice               50260<|summarize|>                -100    masked
# 279     16217     immun        11         ,               50260<|summarize|>                -100    masked
# 280     13437ologically       905      show               50260<|summarize|>                -100    masked
# 281     41492     naïve     20691 reductions               50260<|summarize|>                -100    masked
# 282      3265 population       287        in               50260<|summarize|>                -100    masked
# 283       460       can      9471     virus               50260<|summarize|>                -100    masked
# 284       307        be     30330 replication               50260<|summarize|>                -100    masked
# 285     14101 devastating        11         ,               50260<|summarize|>                -100    masked
# 286        13         .      4369   disease               50260<|summarize|>                -100    masked
# 287       383       The      4371  progress               50260<|summarize|>                -100    masked
# 288      2761  problems       290       and               50260<|summarize|>                -100    masked
# 289       326      that     12430 mortality               50260<|summarize|>                -100    masked
# 290     29491 influenza        13         .               50260<|summarize|>                -100    masked
# 291       317         A     14639        IL               50260<|summarize|>                -100    masked
# 292     20547   viruses        12         -               50260<|summarize|>                -100    masked
# 293      1944   present        16         1               50260<|summarize|>                -100    masked
# 294       329       for        49         R               50260<|summarize|>                -100    masked
# 295      1692     human        16         1               50260<|summarize|>                -100    masked
# 296       290       and     23580 deficiency               50260<|summarize|>                -100    masked
# 297      5044    animal      3568   appears               50260<|summarize|>                -100    masked
# 298      1535    health       284        to               50260<|summarize|>                -100    masked
# 299       389       are      1915       deb               50260<|summarize|>                -100    masked
# 300      6409  numerous      6392      ilit               50260<|summarize|>                -100    masked
# 301        13         .       378       ate               50260<|summarize|>                -100    masked
# 302      1114       For       262       the               50260<|summarize|>                -100    masked
# 303      1672   example      9471     virus               50260<|summarize|>                -100    masked
# 304        11         ,        12         -               50260<|summarize|>                -100    masked
# 305     29491 influenza     17223   induced               50260<|summarize|>                -100    masked
# 306       317         A       277         f               50260<|summarize|>                -100    masked
# 307     20547   viruses      2889       ibr               50260<|summarize|>                -100    masked
# 308       287        in       259        in               50260<|summarize|>                -100    masked
# 309      5384    humans      6644      ogen               50260<|summarize|>                -100    masked
# 310      2380 represent        12         -               50260<|summarize|>                -100    masked
# 311       257         a      2339      like               50260<|summarize|>                -100    masked
# 312      1688     major      7532   protein               50260<|summarize|>                -100    masked
# 313      3034  economic        12         -               50260<|summarize|>                -100    masked
# 314       290       and        17         2               50260<|summarize|>                -100    masked
# 315      4369   disease       357         (               50260<|summarize|>                -100    masked
# 316     10538    burden        37         F               50260<|summarize|>                -100    masked
# 317        11         ,      8763        GL               50260<|summarize|>                -100    masked
# 318     14590    whilst        17         2               50260<|summarize|>                -100    masked
# 319       262       the         8         )               50260<|summarize|>                -100    masked
# 320     34101   poultry      3227 production               50260<|summarize|>                -100    masked
# 321      2831  industry       287        in               50260<|summarize|>                -100    masked
# 322       468       has      8352       mac               50260<|summarize|>                -100    masked
# 323      6989  suffered     10051      roph               50260<|summarize|>                -100    masked
# 324     41197  colossal      1095      ages               50260<|summarize|>                -100    masked
# 325      2465    damage       290       and               50260<|summarize|>                -100    masked
# 326      2233       due      6458        CD               50260<|summarize|>                -100    masked
# 327       256         t      2231        45               50260<|summarize|>                -100    masked
# 328     50256<|endoftext|>         7         (               50260<|summarize|>                -100    masked
# 329     50258     <pad>     28988        +)               50260<|summarize|>                -100    masked
# 330     50258     <pad>      8642        Gr               50260<|summarize|>                -100    masked
# 331     50258     <pad>        12         -               50260<|summarize|>                -100    masked
# 332     50258     <pad>        16         1               50260<|summarize|>                -100    masked
# 333     50258     <pad>         7         (               50260<|summarize|>                -100    masked
# 334     50258     <pad>      8929      high               50260<|summarize|>                -100    masked
# 335     50258     <pad>         8         )               50260<|summarize|>                -100    masked
# 336     50258     <pad>     22190      neut               50260<|summarize|>                -100    masked
# 337     50258     <pad>     10051      roph               50260<|summarize|>                -100    masked
# 338     50258     <pad>       346        il               50260<|summarize|>                -100    masked
# 339     50258     <pad>     45106 infiltration               50260<|summarize|>                -100    masked
# 340     50258     <pad>       287        in               50260<|summarize|>                -100    masked
# 341     50258     <pad>       262       the               50260<|summarize|>                -100    masked
# 342     50258     <pad>     14383     liver               50260<|summarize|>                -100    masked
# 343     50258     <pad>        13         .               50260<|summarize|>                -100    masked
# 344     50258     <pad>       383       The               50260<|summarize|>                -100    masked
# 345     50258     <pad>      2068     quick               50260<|summarize|>                -100    masked
# 346     50258     <pad>      2650   release               50260<|summarize|>                -100    masked
# 347     50258     <pad>       286        of               50260<|summarize|>                -100    masked
# 348     50258     <pad>     32242  reactive               50260<|summarize|>                -100    masked
# 349     50258     <pad>     11863    oxygen               50260<|summarize|>                -100    masked
# 350     50258     <pad>      4693   species               50260<|summarize|>                -100    masked
# 351     50258     <pad>       357         (               50260<|summarize|>                -100    masked
# 352     50258     <pad>        49         R               50260<|summarize|>                -100    masked
# 353     50258     <pad>      2640        OS               50260<|summarize|>                -100    masked
# 354     50258     <pad>         8         )               50260<|summarize|>                -100    masked
# 355     50258     <pad>       416        by               50260<|summarize|>                -100    masked
# 356     50258     <pad>       262       the               50260<|summarize|>                -100    masked
# 357     50258     <pad>     14112  infected               50260<|summarize|>                -100    masked
# 358     50258     <pad>      8352       mac               50260<|summarize|>                -100    masked
# 359     50258     <pad>     10051      roph               50260<|summarize|>                -100    masked
# 360     50258     <pad>      1095      ages               50260<|summarize|>                -100    masked
# 361     50258     <pad>      5644  suggests               50260<|summarize|>                -100    masked
# 362     50258     <pad>       257         a               50260<|summarize|>                -100    masked
# 363     50258     <pad>     19756 plausible               50260<|summarize|>                -100    masked
# 364     50258     <pad>     14416     viral               50260<|summarize|>                -100    masked
# 365     50258     <pad>     30122 initiation               50260<|summarize|>                -100    masked
# 366     50258     <pad>       286        of               50260<|summarize|>                -100    masked
# 367     50258     <pad>     22879        NL               50260<|summarize|>                -100    masked
# 368     50258     <pad>     20031        RP               50260<|summarize|>                -100    masked
# 369     50258     <pad>        18         3               50260<|summarize|>                -100    masked
# 370     50258     <pad>      1167       inf               50260<|summarize|>                -100    masked
# 371     50258     <pad>      2543       lam               50260<|summarize|>                -100    masked
# 372     50258     <pad>      5356       mas               50260<|summarize|>                -100    masked
# 373     50258     <pad>       462       ome               50260<|summarize|>                -100    masked
# 374     50258     <pad>     14916 activation               50260<|summarize|>                -100    masked
# 375     50258     <pad>        13         .               50260<|summarize|>                -100    masked
# 376     50258     <pad>     22384       Fur               50260<|summarize|>                -100    masked
# 377     50258     <pad>     50256<|endoftext|>               50260<|summarize|>                -100    masked
# 378     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 379     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 380     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 381     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 382     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 383     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 384     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 385     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 386     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 387     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 388     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 389     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 390     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 391     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 392     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 393     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 394     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 395     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 396     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 397     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 398     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 399     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 400     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 401     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 402     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 403     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 404     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 405     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 406     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 407     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 408     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 409     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 410     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 411     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 412     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 413     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 414     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 415     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 416     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 417     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 418     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 419     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 420     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 421     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 422     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 423     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 424     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 425     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 426     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 427     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 428     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 429     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 430     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 431     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 432     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 433     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 434     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 435     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 436     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 437     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 438     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 439     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 440     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 441     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 442     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 443     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 444     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 445     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 446     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 447     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 448     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 449     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 450     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 451     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# ...
# 871     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 872     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 873     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 874     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 875     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 876     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 877     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 878     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 879     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 880     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 881     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 882     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 883     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 884     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 885     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 886     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 887     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 888     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 889     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 890     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 891     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 892     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 893     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 894     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 895     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 896     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 897     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 898     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 899     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 900     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 901     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 902     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 903     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 904     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 905     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 906     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 907     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 908     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 909     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 910     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 911     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 912     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 913     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 914     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 915     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 916     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 917     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 918     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 919     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 920     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 921     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 922     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 923     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 924     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 925     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 926     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 927     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 928     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 929     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 930     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 931     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 932     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 933     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 934     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 935     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 936     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 937     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 938     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 939     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 940     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 941     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 942     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 943     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 944     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 945     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 946     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 947     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 948     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 949     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 950     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 951     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 952     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 953     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 954     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 955     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 956     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 957     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 958     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 959     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 960     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 961     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 962     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 963     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 964     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 965     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 966     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 967     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 968     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 969     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 970     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 971     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 972     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 973     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 974     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 975     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 976     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 977     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 978     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 979     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 980     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 981     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 982     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 983     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 984     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 985     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 986     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 987     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 988     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 989     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 990     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 991     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 992     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 993     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 994     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 995     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 996     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 997     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 998     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 999     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1000     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1001     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1002     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1003     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1004     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1005     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1006     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1007     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1008     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1009     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1010     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1011     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1012     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1013     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1014     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1015     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1016     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1017     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1018     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1019     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1020     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1021     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1022     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1023     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked

# %% [markdown]
# # part2: fine-tune-GPT2-for-summarization

# %% [markdown]
# ##0. Using Ignite to train GPT2 summarization¶
# This notebook illustrate how to use Ignite Engine to train GPT2 for abstractive summarization. The goal here is to get a fine-tuned weight tensors of GPT2 that we will later use for abstractive summarization of biomedical science publication. The dataset is processed from this kaggle.
#
# To get a sense on how to train GPT2, and why it is done this way, and what an outcome looks like, read this companion notebook here

# %% [markdown]
# ##1. installing Pytorch, Huggingface, check GPU, etc.¶

# %%
# %cd '/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021'
# Out:
# /content/drive/.shortcut-targets-by-id/17GW73wWB3WJJKQXTdFCaAZX60y4ccAfV/GPT2_Jan28_2021

# %%
# !nvidia-smi
# Out:
# Tue Feb  2 14:56:08 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    11W /  70W |     10MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import matplotlib.pyplot as plt
import timeit
import torch
from torch.utils.data import DataLoader, TensorDataset, RandomSampler


SEED = 1234
torch.manual_seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# !pip install transformers==2.6.0
# Out:
# Requirement already satisfied: transformers==2.6.0 in /usr/local/lib/python3.6/dist-packages (2.6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (0.0.43)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (3.0.12)
# Requirement already satisfied: tokenizers==0.5.2 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (0.5.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (2.23.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (0.1.95)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (2019.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (1.19.5)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (1.16.63)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==2.6.0) (4.41.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.6.0) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.6.0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.6.0) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.6.0) (3.0.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.6.0) (0.3.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.6.0) (0.10.0)
# Requirement already satisfied: botocore<1.20.0,>=1.19.63 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.6.0) (1.19.63)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.20.0,>=1.19.63->boto3->transformers==2.6.0) (2.8.1)

# %%
import transformers
from transformers import GPT2Tokenizer, GPT2DoubleHeadsModel, AdamW
load_model = False
load_previous_weight = False
resize_model = False
print(transformers.__version__) # make sure it is 2.6.0
# Out:
# 2.6.0

# %% [markdown]
# ##2. Test load the GPT2DoubleHeadsModel¶

# %%
model = GPT2DoubleHeadsModel.from_pretrained('/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021')
load_model = True

# %%
tokenizer = GPT2Tokenizer.from_pretrained('/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021')

# %%
print(len(tokenizer), 'total length of vocab') # expect 50257
# Out:
# 50257 total length of vocab

# %%
# Add a [CLS] to the vocabulary (we should train it also!)
special_tokens = {'bos_token':'<|startoftext|>','eos_token':'<|endoftext|>','pad_token':'<pad>','additional_special_tokens':['<|keyword|>','<|summarize|>']}
#special_tokens2 = {'bos_token':'<|startoftext|>','eos_token':'<|endoftext|>','keyword_token':'<|keyword|>','summary_token':'<|summarize|>'}
tokenizer.add_special_tokens(special_tokens)
#model.resize_token_embeddings(len(tokenizer))  # Update the model embeddings with the new vocabulary size
# The newly token the last token of the vocabulary
resize_model = True

# %%
print(len(tokenizer), 'total length of vocab')
print(tokenizer.bos_token_id, 'bos_token')
print(tokenizer.eos_token_id, 'eos_token')
print(tokenizer.pad_token_id, 'pad_token')  #token for <pad>, len of all tokens in the tokenizer
print(tokenizer.additional_special_tokens_ids[0], 'keyword_token') #token for <|keyword|>
print(tokenizer.additional_special_tokens_ids[1], 'summary_token') #token for <|summarize|>
# Out:
# 50261 total length of vocab
# 50257 bos_token
# 50256 eos_token
# 50258 pad_token
# 50259 keyword_token
# 50260 summary_token

# %% [markdown]
# ##3. Load dataset and make dataloader
#
# The dataset is in the torch tensor format. It is bundled into a tuple of 5 items, which are
#
# 1. the input tokens.
# 2. the segment tokens.
# 3. the index for last token (this is used for multiple choice),
# 4. the language model expected output tokens, the masked [-100] is used to mask away part that model doesn't have to output.
#
#   - this 1-4 items come in a batch of 4, only one of these 4 is the correct keyword-summary pair. The other 3 are distractors.
# 5. the multiple choice label which one of the 4 item in the current batch is the correct choice.

# %%
train_dataset_1 = torch.load('/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021/post_processed_train_tensor.pt')

# %%
len(train_dataset_1)
train_dataset_1[5]
# Out:
# (tensor([[50257, 21918,  2708,  ..., 50258, 50258, 50258],
#          [50257, 21918,  2708,  ..., 50258, 50258, 50258],
#          [50257, 21918,  2708,  ..., 50258, 50258, 50258],
#          [50257, 21918,  2708,  ..., 50258, 50258, 50258]]),
#  tensor([[50259, 50259, 50259,  ..., 50258, 50258, 50258],
#          [50259, 50259, 50259,  ..., 50258, 50258, 50258],
#          [50259, 50259, 50259,  ..., 50258, 50258, 50258],
#          [50259, 50259, 50259,  ..., 50258, 50258, 50258]]),
#  tensor([394, 487,  71,  71]),
#  tensor([[-100, -100, -100,  ..., -100, -100, -100],
#          [-100, -100, -100,  ..., -100, -100, -100],
#          [-100, -100, -100,  ..., -100, -100, -100],
#          [-100, -100, -100,  ..., -100, -100, -100]]),
#  tensor([2]))

# %%
for count,i in enumerate(train_dataset_1[5][3][0]):
  i = int(i)
  if i == -100:
    decode_i = 'masked'
  else:
    decode_i = tokenizer.decode(i)
  print(count,int(i), decode_i)
# Out:
# 0 -100 masked
# 1 -100 masked
# 2 -100 masked
# 3 -100 masked
# 4 -100 masked
# 5 -100 masked
# 6 -100 masked
# 7 -100 masked
# 8 -100 masked
# 9 -100 masked
# 10 -100 masked
# 11 -100 masked
# 12 -100 masked
# 13 -100 masked
# 14 -100 masked
# 15 -100 masked
# 16 -100 masked
# 17 -100 masked
# 18 -100 masked
# 19 -100 masked
# 20 -100 masked
# 21 -100 masked
# 22 -100 masked
# 23 -100 masked
# 24 -100 masked
# 25 -100 masked
# 26 -100 masked
# 27 -100 masked
# 28 -100 masked
# 29 -100 masked
# 30 -100 masked
# 31 -100 masked
# 32 -100 masked
# 33 -100 masked
# 34 -100 masked
# 35 -100 masked
# 36 -100 masked
# 37 -100 masked
# 38 -100 masked
# 39 -100 masked
# 40 -100 masked
# 41 -100 masked
# 42 -100 masked
# 43 -100 masked
# 44 -100 masked
# 45 -100 masked
# 46 -100 masked
# 47 -100 masked
# 48 -100 masked
# 49 -100 masked
# 50 -100 masked
# 51 -100 masked
# 52 -100 masked
# 53 -100 masked
# 54 -100 masked
# 55 -100 masked
# 56 -100 masked
# 57 -100 masked
# 58 -100 masked
# 59 -100 masked
# 60 -100 masked
# 61 -100 masked
# 62 -100 masked
# 63 -100 masked
# 64 -100 masked
# 65 -100 masked
# 66 -100 masked
# 67 -100 masked
# 68 -100 masked
# 69 -100 masked
# 70 -100 masked
# 71 -100 masked
# 72 -100 masked
# 73 -100 masked
# 74 -100 masked
# 75 -100 masked
# 76 -100 masked
# 77 -100 masked
# 78 -100 masked
# 79 -100 masked
# 80 -100 masked
# 81 -100 masked
# 82 -100 masked
# 83 -100 masked
# 84 -100 masked
# 85 -100 masked
# 86 -100 masked
# 87 -100 masked
# 88 -100 masked
# 89 -100 masked
# 90 -100 masked
# 91 -100 masked
# 92 -100 masked
# 93 -100 masked
# 94 -100 masked
# 95 -100 masked
# 96 -100 masked
# 97 -100 masked
# 98 -100 masked
# 99 -100 masked
# 100 -100 masked
# 101 -100 masked
# 102 -100 masked
# 103 -100 masked
# 104 -100 masked
# 105 -100 masked
# 106 -100 masked
# 107 -100 masked
# 108 -100 masked
# 109 -100 masked
# 110 -100 masked
# 111 -100 masked
# 112 -100 masked
# 113 -100 masked
# 114 -100 masked
# 115 -100 masked
# 116 -100 masked
# 117 -100 masked
# 118 -100 masked
# 119 -100 masked
# 120 -100 masked
# 121 -100 masked
# 122 -100 masked
# 123 -100 masked
# 124 -100 masked
# 125 -100 masked
# 126 -100 masked
# 127 -100 masked
# 128 -100 masked
# 129 -100 masked
# 130 -100 masked
# 131 -100 masked
# 132 -100 masked
# 133 -100 masked
# 134 -100 masked
# 135 -100 masked
# 136 -100 masked
# 137 -100 masked
# 138 -100 masked
# 139 -100 masked
# 140 -100 masked
# 141 -100 masked
# 142 -100 masked
# 143 -100 masked
# 144 -100 masked
# 145 -100 masked
# 146 -100 masked
# 147 -100 masked
# 148 -100 masked
# 149 -100 masked
# 150 -100 masked
# 151 -100 masked
# 152 -100 masked
# 153 -100 masked
# 154 -100 masked
# 155 -100 masked
# 156 -100 masked
# 157 -100 masked
# 158 -100 masked
# 159 -100 masked
# 160 -100 masked
# 161 -100 masked
# 162 -100 masked
# 163 -100 masked
# 164 -100 masked
# 165 -100 masked
# 166 -100 masked
# 167 -100 masked
# 168 -100 masked
# 169 -100 masked
# 170 -100 masked
# 171 -100 masked
# 172 -100 masked
# 173 -100 masked
# 174 -100 masked
# 175 -100 masked
# 176 -100 masked
# 177 -100 masked
# 178 -100 masked
# 179 -100 masked
# 180 -100 masked
# 181 -100 masked
# 182 -100 masked
# 183 -100 masked
# 184 -100 masked
# 185 -100 masked
# 186 -100 masked
# 187 -100 masked
# 188 -100 masked
# 189 -100 masked
# 190 -100 masked
# 191 -100 masked
# 192 -100 masked
# 193 -100 masked
# 194 -100 masked
# 195 -100 masked
# 196 -100 masked
# 197 -100 masked
# 198 -100 masked
# 199 -100 masked
# 200 -100 masked
# 201 -100 masked
# 202 -100 masked
# 203 -100 masked
# 204 -100 masked
# 205 -100 masked
# 206 -100 masked
# 207 -100 masked
# 208 -100 masked
# 209 -100 masked
# 210 -100 masked
# 211 -100 masked
# 212 -100 masked
# 213 -100 masked
# 214 -100 masked
# 215 -100 masked
# 216 -100 masked
# 217 -100 masked
# 218 -100 masked
# 219 -100 masked
# 220 -100 masked
# 221 -100 masked
# 222 -100 masked
# 223 -100 masked
# 224 -100 masked
# 225 -100 masked
# 226 -100 masked
# 227 -100 masked
# 228 -100 masked
# 229 -100 masked
# 230 -100 masked
# 231 -100 masked
# 232 -100 masked
# 233 -100 masked
# 234 -100 masked
# 235 -100 masked
# 236 -100 masked
# 237 -100 masked
# 238 -100 masked
# 239 -100 masked
# 240 -100 masked
# 241 -100 masked
# 242 -100 masked
# 243 -100 masked
# 244 -100 masked
# 245 -100 masked
# 246 -100 masked
# 247 -100 masked
# 248 -100 masked
# 249 -100 masked
# 250 -100 masked
# 251 -100 masked
# 252 -100 masked
# 253 -100 masked
# 254 -100 masked
# 255 -100 masked
# 256 -100 masked
# 257 -100 masked
# 258 -100 masked
# 259 -100 masked
# 260 -100 masked
# 261 -100 masked
# 262 -100 masked
# 263 -100 masked
# 264 -100 masked
# 265 -100 masked
# 266 -100 masked
# 267 -100 masked
# 268 -100 masked
# 269 -100 masked
# 270 -100 masked
# 271 -100 masked
# 272 -100 masked
# 273 -100 masked
# 274 -100 masked
# 275 -100 masked
# 276 -100 masked
# 277 -100 masked
# 278 -100 masked
# 279 -100 masked
# 280 -100 masked
# 281 -100 masked
# 282 -100 masked
# 283 -100 masked
# 284 -100 masked
# 285 -100 masked
# 286 -100 masked
# 287 -100 masked
# 288 -100 masked
# 289 -100 masked
# 290 -100 masked
# 291 -100 masked
# 292 -100 masked
# 293 -100 masked
# 294 -100 masked
# 295 -100 masked
# 296 -100 masked
# 297 -100 masked
# 298 -100 masked
# 299 -100 masked
# 300 -100 masked
# 301 -100 masked
# 302 -100 masked
# 303 -100 masked
# 304 -100 masked
# 305 -100 masked
# 306 -100 masked
# 307 -100 masked
# 308 -100 masked
# 309 -100 masked
# 310 -100 masked
# 311 -100 masked
# 312 -100 masked
# 313 -100 masked
# 314 -100 masked
# 315 -100 masked
# 316 -100 masked
# 317 -100 masked
# 318 -100 masked
# 319 -100 masked
# 320 -100 masked
# 321 -100 masked
# 322 -100 masked
# 323 -100 masked
# 324 -100 masked
# 325 -100 masked
# 326 -100 masked
# 327 -100 masked
# 328 -100 masked
# 329 -100 masked
# 330 -100 masked
# 331 -100 masked
# 332 -100 masked
# 333 -100 masked
# 334 -100 masked
# 335 -100 masked
# 336 -100 masked
# 337 -100 masked
# 338 -100 masked
# 339 -100 masked
# 340 -100 masked
# 341 -100 masked
# 342 -100 masked
# 343 -100 masked
# 344 -100 masked
# 345 -100 masked
# 346 -100 masked
# 347 -100 masked
# 348 -100 masked
# 349 -100 masked
# 350 -100 masked
# 351 -100 masked
# 352 -100 masked
# 353 -100 masked
# 354 -100 masked
# 355 -100 masked
# 356 -100 masked
# 357 -100 masked
# 358 -100 masked
# 359 -100 masked
# 360 -100 masked
# 361 -100 masked
# 362 -100 masked
# 363 -100 masked
# 364 -100 masked
# 365 -100 masked
# 366 -100 masked
# 367 -100 masked
# 368 -100 masked
# 369 -100 masked
# 370 -100 masked
# 371 -100 masked
# 372 -100 masked
# 373 -100 masked
# 374 -100 masked
# 375 -100 masked
# 376 -100 masked
# 377 -100 masked
# 378 -100 masked
# 379 -100 masked
# 380 -100 masked
# 381 -100 masked
# 382 -100 masked
# 383 -100 masked
# 384 -100 masked
# 385 -100 masked
# 386 -100 masked
# 387 -100 masked
# 388 -100 masked
# 389 -100 masked
# 390 -100 masked
# 391 -100 masked
# 392 -100 masked
# 393 -100 masked
# 394 -100 masked
# 395 -100 masked
# 396 -100 masked
# 397 -100 masked
# 398 -100 masked
# 399 -100 masked
# 400 -100 masked
# 401 -100 masked
# 402 -100 masked
# 403 -100 masked
# 404 -100 masked
# 405 -100 masked
# 406 -100 masked
# 407 -100 masked
# 408 -100 masked
# 409 -100 masked
# 410 -100 masked
# 411 -100 masked
# 412 -100 masked
# 413 -100 masked
# 414 -100 masked
# 415 -100 masked
# 416 -100 masked
# 417 -100 masked
# 418 -100 masked
# 419 -100 masked
# 420 -100 masked
# 421 -100 masked
# 422 -100 masked
# 423 -100 masked
# 424 -100 masked
# 425 -100 masked
# 426 -100 masked
# 427 -100 masked
# 428 -100 masked
# 429 -100 masked
# 430 -100 masked
# 431 -100 masked
# 432 -100 masked
# 433 -100 masked
# 434 -100 masked
# 435 -100 masked
# 436 -100 masked
# 437 -100 masked
# 438 -100 masked
# 439 -100 masked
# 440 -100 masked
# 441 -100 masked
# 442 -100 masked
# 443 -100 masked
# 444 -100 masked
# 445 -100 masked
# 446 -100 masked
# 447 -100 masked
# 448 -100 masked
# 449 -100 masked
# 450 -100 masked
# 451 -100 masked
# 452 -100 masked
# 453 -100 masked
# 454 -100 masked
# 455 -100 masked
# 456 -100 masked
# 457 -100 masked
# 458 -100 masked
# 459 -100 masked
# 460 -100 masked
# 461 -100 masked
# 462 -100 masked
# 463 -100 masked
# 464 -100 masked
# 465 -100 masked
# 466 -100 masked
# 467 -100 masked
# 468 -100 masked
# 469 -100 masked
# 470 -100 masked
# 471 -100 masked
# 472 -100 masked
# 473 -100 masked
# 474 -100 masked
# 475 -100 masked
# 476 -100 masked
# 477 -100 masked
# 478 -100 masked
# 479 -100 masked
# 480 -100 masked
# 481 -100 masked
# 482 -100 masked
# 483 -100 masked
# 484 -100 masked
# 485 -100 masked
# 486 -100 masked
# 487 -100 masked
# 488 -100 masked
# 489 -100 masked
# 490 -100 masked
# 491 -100 masked
# 492 -100 masked
# 493 -100 masked
# 494 -100 masked
# 495 -100 masked
# 496 -100 masked
# 497 -100 masked
# 498 -100 masked
# 499 -100 masked
# 500 -100 masked
# 501 -100 masked
# 502 -100 masked
# 503 -100 masked
# 504 -100 masked
# 505 -100 masked
# 506 -100 masked
# 507 -100 masked
# 508 -100 masked
# 509 -100 masked
# 510 -100 masked
# 511 -100 masked
# 512 -100 masked
# 513 -100 masked
# 514 -100 masked
# 515 -100 masked
# 516 -100 masked
# 517 -100 masked
# 518 -100 masked
# 519 -100 masked
# 520 -100 masked
# 521 -100 masked
# 522 -100 masked
# 523 -100 masked
# 524 -100 masked
# 525 -100 masked
# 526 -100 masked
# 527 -100 masked
# 528 -100 masked
# 529 -100 masked
# 530 -100 masked
# 531 -100 masked
# 532 -100 masked
# 533 -100 masked
# 534 -100 masked
# 535 -100 masked
# 536 -100 masked
# 537 -100 masked
# 538 -100 masked
# 539 -100 masked
# 540 -100 masked
# 541 -100 masked
# 542 -100 masked
# 543 -100 masked
# 544 -100 masked
# 545 -100 masked
# 546 -100 masked
# 547 -100 masked
# 548 -100 masked
# 549 -100 masked
# 550 -100 masked
# 551 -100 masked
# 552 -100 masked
# 553 -100 masked
# 554 -100 masked
# 555 -100 masked
# 556 -100 masked
# 557 -100 masked
# 558 -100 masked
# 559 -100 masked
# 560 -100 masked
# 561 -100 masked
# 562 -100 masked
# 563 -100 masked
# 564 -100 masked
# 565 -100 masked
# 566 -100 masked
# 567 -100 masked
# 568 -100 masked
# 569 -100 masked
# 570 -100 masked
# 571 -100 masked
# 572 -100 masked
# 573 -100 masked
# 574 -100 masked
# 575 -100 masked
# 576 -100 masked
# 577 -100 masked
# 578 -100 masked
# 579 -100 masked
# 580 -100 masked
# 581 -100 masked
# 582 -100 masked
# 583 -100 masked
# 584 -100 masked
# 585 -100 masked
# 586 -100 masked
# 587 -100 masked
# 588 -100 masked
# 589 -100 masked
# 590 -100 masked
# 591 -100 masked
# 592 -100 masked
# 593 -100 masked
# 594 -100 masked
# 595 -100 masked
# 596 -100 masked
# 597 -100 masked
# 598 -100 masked
# 599 -100 masked
# 600 -100 masked
# 601 -100 masked
# 602 -100 masked
# 603 -100 masked
# 604 -100 masked
# 605 -100 masked
# 606 -100 masked
# 607 -100 masked
# 608 -100 masked
# 609 -100 masked
# 610 -100 masked
# 611 -100 masked
# 612 -100 masked
# 613 -100 masked
# 614 -100 masked
# 615 -100 masked
# 616 -100 masked
# 617 -100 masked
# 618 -100 masked
# 619 -100 masked
# 620 -100 masked
# 621 -100 masked
# 622 -100 masked
# 623 -100 masked
# 624 -100 masked
# 625 -100 masked
# 626 -100 masked
# 627 -100 masked
# 628 -100 masked
# 629 -100 masked
# 630 -100 masked
# 631 -100 masked
# 632 -100 masked
# 633 -100 masked
# 634 -100 masked
# 635 -100 masked
# 636 -100 masked
# 637 -100 masked
# 638 -100 masked
# 639 -100 masked
# 640 -100 masked
# 641 -100 masked
# 642 -100 masked
# 643 -100 masked
# 644 -100 masked
# 645 -100 masked
# 646 -100 masked
# 647 -100 masked
# 648 -100 masked
# 649 -100 masked
# 650 -100 masked
# 651 -100 masked
# 652 -100 masked
# 653 -100 masked
# 654 -100 masked
# 655 -100 masked
# 656 -100 masked
# 657 -100 masked
# 658 -100 masked
# 659 -100 masked
# 660 -100 masked
# 661 -100 masked
# 662 -100 masked
# 663 -100 masked
# 664 -100 masked
# 665 -100 masked
# 666 -100 masked
# 667 -100 masked
# 668 -100 masked
# 669 -100 masked
# 670 -100 masked
# 671 -100 masked
# 672 -100 masked
# 673 -100 masked
# 674 -100 masked
# 675 -100 masked
# 676 -100 masked
# 677 -100 masked
# 678 -100 masked
# 679 -100 masked
# 680 -100 masked
# 681 -100 masked
# 682 -100 masked
# 683 -100 masked
# 684 -100 masked
# 685 -100 masked
# 686 -100 masked
# 687 -100 masked
# 688 -100 masked
# 689 -100 masked
# 690 -100 masked
# 691 -100 masked
# 692 -100 masked
# 693 -100 masked
# 694 -100 masked
# 695 -100 masked
# 696 -100 masked
# 697 -100 masked
# 698 -100 masked
# 699 -100 masked
# 700 -100 masked
# 701 -100 masked
# 702 -100 masked
# 703 -100 masked
# 704 -100 masked
# 705 -100 masked
# 706 -100 masked
# 707 -100 masked
# 708 -100 masked
# 709 -100 masked
# 710 -100 masked
# 711 -100 masked
# 712 -100 masked
# 713 -100 masked
# 714 -100 masked
# 715 -100 masked
# 716 -100 masked
# 717 -100 masked
# 718 -100 masked
# 719 -100 masked
# 720 -100 masked
# 721 -100 masked
# 722 -100 masked
# 723 -100 masked
# 724 -100 masked
# 725 -100 masked
# 726 -100 masked
# 727 -100 masked
# 728 -100 masked
# 729 -100 masked
# 730 -100 masked
# 731 -100 masked
# 732 -100 masked
# 733 -100 masked
# 734 -100 masked
# 735 -100 masked
# 736 -100 masked
# 737 -100 masked
# 738 -100 masked
# 739 -100 masked
# 740 -100 masked
# 741 -100 masked
# 742 -100 masked
# 743 -100 masked
# 744 -100 masked
# 745 -100 masked
# 746 -100 masked
# 747 -100 masked
# 748 -100 masked
# 749 -100 masked
# 750 -100 masked
# 751 -100 masked
# 752 -100 masked
# 753 -100 masked
# 754 -100 masked
# 755 -100 masked
# 756 -100 masked
# 757 -100 masked
# 758 -100 masked
# 759 -100 masked
# 760 -100 masked
# 761 -100 masked
# 762 -100 masked
# 763 -100 masked
# 764 -100 masked
# 765 -100 masked
# 766 -100 masked
# 767 -100 masked
# 768 -100 masked
# 769 -100 masked
# 770 -100 masked
# 771 -100 masked
# 772 -100 masked
# 773 -100 masked
# 774 -100 masked
# 775 -100 masked
# 776 -100 masked
# 777 -100 masked
# 778 -100 masked
# 779 -100 masked
# 780 -100 masked
# 781 -100 masked
# 782 -100 masked
# 783 -100 masked
# 784 -100 masked
# 785 -100 masked
# 786 -100 masked
# 787 -100 masked
# 788 -100 masked
# 789 -100 masked
# 790 -100 masked
# 791 -100 masked
# 792 -100 masked
# 793 -100 masked
# 794 -100 masked
# 795 -100 masked
# 796 -100 masked
# 797 -100 masked
# 798 -100 masked
# 799 -100 masked
# 800 -100 masked
# 801 -100 masked
# 802 -100 masked
# 803 -100 masked
# 804 -100 masked
# 805 -100 masked
# 806 -100 masked
# 807 -100 masked
# 808 -100 masked
# 809 -100 masked
# 810 -100 masked
# 811 -100 masked
# 812 -100 masked
# 813 -100 masked
# 814 -100 masked
# 815 -100 masked
# 816 -100 masked
# 817 -100 masked
# 818 -100 masked
# 819 -100 masked
# 820 -100 masked
# 821 -100 masked
# 822 -100 masked
# 823 -100 masked
# 824 -100 masked
# 825 -100 masked
# 826 -100 masked
# 827 -100 masked
# 828 -100 masked
# 829 -100 masked
# 830 -100 masked
# 831 -100 masked
# 832 -100 masked
# 833 -100 masked
# 834 -100 masked
# 835 -100 masked
# 836 -100 masked
# 837 -100 masked
# 838 -100 masked
# 839 -100 masked
# 840 -100 masked
# 841 -100 masked
# 842 -100 masked
# 843 -100 masked
# 844 -100 masked
# 845 -100 masked
# 846 -100 masked
# 847 -100 masked
# 848 -100 masked
# 849 -100 masked
# 850 -100 masked
# 851 -100 masked
# 852 -100 masked
# 853 -100 masked
# 854 -100 masked
# 855 -100 masked
# 856 -100 masked
# 857 -100 masked
# 858 -100 masked
# 859 -100 masked
# 860 -100 masked
# 861 -100 masked
# 862 -100 masked
# 863 -100 masked
# 864 -100 masked
# 865 -100 masked
# 866 -100 masked
# 867 -100 masked
# 868 -100 masked
# 869 -100 masked
# 870 -100 masked
# 871 -100 masked
# 872 -100 masked
# 873 -100 masked
# 874 -100 masked
# 875 -100 masked
# 876 -100 masked
# 877 -100 masked
# 878 -100 masked
# 879 -100 masked
# 880 -100 masked
# 881 -100 masked
# 882 -100 masked
# 883 -100 masked
# 884 -100 masked
# 885 -100 masked
# 886 -100 masked
# 887 -100 masked
# 888 -100 masked
# 889 -100 masked
# 890 -100 masked
# 891 -100 masked
# 892 -100 masked
# 893 -100 masked
# 894 -100 masked
# 895 -100 masked
# 896 -100 masked
# 897 -100 masked
# 898 -100 masked
# 899 -100 masked
# 900 -100 masked
# 901 -100 masked
# 902 -100 masked
# 903 -100 masked
# 904 -100 masked
# 905 -100 masked
# 906 -100 masked
# 907 -100 masked
# 908 -100 masked
# 909 -100 masked
# 910 -100 masked
# 911 -100 masked
# 912 -100 masked
# 913 -100 masked
# 914 -100 masked
# 915 -100 masked
# 916 -100 masked
# 917 -100 masked
# 918 -100 masked
# 919 -100 masked
# 920 -100 masked
# 921 -100 masked
# 922 -100 masked
# 923 -100 masked
# 924 -100 masked
# 925 -100 masked
# 926 -100 masked
# 927 -100 masked
# 928 -100 masked
# 929 -100 masked
# 930 -100 masked
# 931 -100 masked
# 932 -100 masked
# 933 -100 masked
# 934 -100 masked
# 935 -100 masked
# 936 -100 masked
# 937 -100 masked
# 938 -100 masked
# 939 -100 masked
# 940 -100 masked
# 941 -100 masked
# 942 -100 masked
# 943 -100 masked
# 944 -100 masked
# 945 -100 masked
# 946 -100 masked
# 947 -100 masked
# 948 -100 masked
# 949 -100 masked
# 950 -100 masked
# 951 -100 masked
# 952 -100 masked
# 953 -100 masked
# 954 -100 masked
# 955 -100 masked
# 956 -100 masked
# 957 -100 masked
# 958 -100 masked
# 959 -100 masked
# 960 -100 masked
# 961 -100 masked
# 962 -100 masked
# 963 -100 masked
# 964 -100 masked
# 965 -100 masked
# 966 -100 masked
# 967 -100 masked
# 968 -100 masked
# 969 -100 masked
# 970 -100 masked
# 971 -100 masked
# 972 -100 masked
# 973 -100 masked
# 974 -100 masked
# 975 -100 masked
# 976 -100 masked
# 977 -100 masked
# 978 -100 masked
# 979 -100 masked
# 980 -100 masked
# 981 -100 masked
# 982 -100 masked
# 983 -100 masked
# 984 -100 masked
# 985 -100 masked
# 986 -100 masked
# 987 -100 masked
# 988 -100 masked
# 989 -100 masked
# 990 -100 masked
# 991 -100 masked
# 992 -100 masked
# 993 -100 masked
# 994 -100 masked
# 995 -100 masked
# 996 -100 masked
# 997 -100 masked
# 998 -100 masked
# 999 -100 masked
# 1000 -100 masked
# 1001 -100 masked
# 1002 -100 masked
# 1003 -100 masked
# 1004 -100 masked
# 1005 -100 masked
# 1006 -100 masked
# 1007 -100 masked
# 1008 -100 masked
# 1009 -100 masked
# 1010 -100 masked
# 1011 -100 masked
# 1012 -100 masked
# 1013 -100 masked
# 1014 -100 masked
# 1015 -100 masked
# 1016 -100 masked
# 1017 -100 masked
# 1018 -100 masked
# 1019 -100 masked
# 1020 -100 masked
# 1021 -100 masked
# 1022 -100 masked
# 1023 -100 masked

# %%
train1_sampler = RandomSampler(train_dataset_1)
train1_dataloader = DataLoader(train_dataset_1, sampler=train1_sampler, batch_size=1)

# %%
val_dataset_1 = torch.load('/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021/post_processed_val_tensor.pt')
val1_sampler = RandomSampler(val_dataset_1)
val1_dataloader = DataLoader(val_dataset_1, sampler=val1_sampler, batch_size=1)

# %% [markdown]
# ##4. Test run

# %%
input_ids, token_type_ids, mc_token_ids, lm_labels, mc_labels = train_dataset_1[0]
print(input_ids.shape)
print(token_type_ids.shape)
print(mc_token_ids.shape)
print(lm_labels.shape)
print(mc_labels.shape)
# Out:
# torch.Size([4, 1024])
# torch.Size([4, 1024])
# torch.Size([4])
# torch.Size([4, 1024])
# torch.Size([1])

# %%
model = model.to(device)
optimizer = AdamW(model.parameters(),lr=3e-5,eps=1e-8, correct_bias=True)
max_norm = 1.0

# %%
gradient_accumulation_steps = 10

# %%
total_steps = len(train1_dataloader)
print('total step for learning rate scheduler = ',total_steps)
# Out:
# total step for learning rate scheduler =  31974

# %%
from transformers import get_linear_schedule_with_warmup
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps = 50, num_training_steps = total_steps)

# %%
test_run = train_dataset_1[1]

# %%
# Forward pass
start = timeit.default_timer()
model.train()
optimizer.zero_grad()
test_run = (item.to(device) for item in test_run)
input_ids, token_type_ids, mc_token_ids, lm_labels, mc_labels = test_run
#input_ids, mc_token_ids, lm_labels, mc_labels, token_type_ids = input_ids.to(device), mc_token_ids.to(device), lm_labels.to(device), mc_labels.to(device), token_type_ids.to(device)
outputs = model(input_ids = input_ids, mc_token_ids = mc_token_ids, mc_labels = mc_labels, lm_labels = lm_labels, token_type_ids = token_type_ids)
lm_loss, mc_loss = outputs[0], outputs[1]

lm_coef = 2.0
mc_coef = 1.0

total_loss = lm_loss * lm_coef + mc_loss * mc_coef
print('lm_loss = ',lm_loss.item())
print('mc_loss = ',mc_loss.item())
print('total_loss = ',total_loss.item())
total_loss.backward()
torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm)
optimizer.step()
stop = timeit.default_timer()
print('1 epoch takes {:.3f}'.format(stop - start),' sec')
# Out:
# lm_loss =  1.4279698133468628
# mc_loss =  0.0
# total_loss =  2.8559396266937256
# 1 epoch takes 1.043  sec
# /usr/local/lib/python3.6/dist-packages/transformers/optimization.py:155: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)

# %% [markdown]
# ##5. set up Ignite

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/17GW73wWB3WJJKQXTdFCaAZX60y4ccAfV/GPT2_Jan28_2021

# %%
# !pip install pytorch-ignite

# %%
from ignite.engine import Engine, Events
from ignite.metrics import MeanSquaredError, Loss, RunningAverage
from ignite.handlers import ModelCheckpoint, EarlyStopping

# %%
def process_function(engine,batch):
  #start = timeit.default_timer()
  model.train()
  #optimizer.zero_grad()
  batch = (item.to(device) for item in batch)
  input_ids, token_type_ids, mc_token_ids, lm_labels, mc_labels = batch
  outputs = model(input_ids = input_ids, mc_token_ids = mc_token_ids, mc_labels = mc_labels,
                  lm_labels = lm_labels, token_type_ids = token_type_ids)
  lm_loss, mc_loss = outputs[0], outputs[1]
  #del input_ids, token_type_ids, mc_token_ids, lm_labels, mc_labels
  lm_coef = 2.0
  mc_coef = 1.0
  total_loss = lm_loss * lm_coef + mc_loss * mc_coef
  total_loss = total_loss / gradient_accumulation_steps
  total_loss.backward()
  torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm)
  if engine.state.iteration % gradient_accumulation_steps == 0:
    optimizer.step()
    optimizer.zero_grad()
  scheduler.step()
  return lm_loss.item(),mc_loss.item(),total_loss.item()*gradient_accumulation_steps

# %%
def evaluate_function(engine,batch):
  model.eval()
  with torch.no_grad():
    batch = (item.to(device) for item in batch)
    input_ids, token_type_ids, mc_token_ids, lm_labels, mc_labels = batch
    outputs = model(input_ids = input_ids, mc_token_ids = mc_token_ids, mc_labels = mc_labels,
                  lm_labels = lm_labels, token_type_ids = token_type_ids)
    lm_loss, mc_loss = outputs[0], outputs[1]
    lm_coef = 2.0
    mc_coef = 1.0
    total_loss = lm_loss * lm_coef + mc_loss * mc_coef
  return lm_loss.item(),mc_loss.item(),total_loss.item()

# %%
trainer = Engine(process_function)
evaluator = Engine(evaluate_function)

training_history = {'lm_loss': [], 'mc_loss': [], 'total_loss': []}
validation_history = {'lm_loss': [], 'mc_loss': [], 'total_loss': []}

# %%
RunningAverage(output_transform=lambda x: x[0]).attach(trainer, 'lm_loss')
RunningAverage(output_transform=lambda x: x[1]).attach(trainer, 'mc_loss')
RunningAverage(output_transform=lambda x: x[2]).attach(trainer, 'total_loss')

# %%
RunningAverage(output_transform=lambda x: x[0]).attach(evaluator, 'lm_loss')
RunningAverage(output_transform=lambda x: x[1]).attach(evaluator, 'mc_loss')
RunningAverage(output_transform=lambda x: x[2]).attach(evaluator, 'total_loss')

# %%
@trainer.on(Events.ITERATION_COMPLETED(every=100))
def print_trainer_logs(engine):
    # try:
    #   start
    # except:
    #   start = timeit.default_timer()
    loss_LM = engine.state.metrics['lm_loss']
    loss_NSP = engine.state.metrics['mc_loss']
    combined_loss = engine.state.metrics['total_loss']
    stop = timeit.default_timer()
    print("Trainer Results - iteration {} - LM loss: {:.2f} MC loss: {:.2f} total loss: {:.2f} report time: {:.1f}"
    .format(engine.state.iteration, loss_LM, loss_NSP, combined_loss,stop))

# %%
checkpointer = ModelCheckpoint('/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021/GPT2_dir', 'GPT2_summarizer', n_saved=2, create_dir=True, save_as_state_dict=True,require_empty=False)
trainer.add_event_handler(Events.ITERATION_COMPLETED(every=15000), checkpointer, {'epoch_2': model})
trainer.add_event_handler(Events.EPOCH_COMPLETED, checkpointer, {'epoch_2_done': model})

# %%
def print_logs(engine, dataloader, mode, history_dict):
    evaluator.run(dataloader, max_epochs=1)
    metrics = evaluator.state.metrics
    avg_LM_loss = metrics['lm_loss']
    avg_NSP_loss = metrics['mc_loss']
    avg_total_loss = metrics['total_loss']
    #avg_loss =  avg_bce + avg_kld
    print(
        mode + " Results - Epoch {} - Avg lm_loss: {:.2f} Avg mc_loss: {:.2f} Avg total_loss: {:.2f}"
        .format(engine.state.epoch, avg_LM_loss, avg_NSP_loss, avg_total_loss))
    for key in evaluator.state.metrics.keys():
        history_dict[key].append(evaluator.state.metrics[key])

trainer.add_event_handler(Events.EPOCH_COMPLETED, print_logs, val1_dataloader, 'Validation', validation_history)

# %% [markdown]
# ##Run Ignite Engine

# %%
e = trainer.run(train1_dataloader, max_epochs=1)

# %% [markdown]
# #part3: generate-summary-with-BERT-or-GPT2

# %%
# !pip install -r /content/drive/MyDrive/Covid_Summary/requirements.txt

# %%
# !python /content/drive/MyDrive/Covid_Summary/GPT2_summarize.py --input_file='/content/drive/MyDrive/Covid_Summary/covid.txt' --model_directory='/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021'

# %% [markdown]
# ##Generating a summary of COVID19 publication¶
# This notebook introduces a NLP approach to summarize a and paraphrase a scientific publication. The model is specifically trained on COVID19 related data released as part of the COVID-19 Open Research Dataset Challenge on Kaggle.
#
# The strategy we'll be using here involve
#
# 1. extract sentences using BERT + clustering
# 2. extract keyword tokens from the extracted sentences using BERT fine-tuned for token classification
# 3. generate a paraphrases from the extracted keywords using GPT2 fine-tuned for making abstractive summarization from keywords
#
#
# The fine-tuning is already done, so we will load the model weights to perform the task. GPU is not necessary for this task,but it should help speed things up a bit, especially at the GPT2 sentence generation step.

# %%
#title Setup Environment and helper function
# Pip install Huggingface transformers

# if cuda is available, set device = 'cuda'

# setup pytorch environment

# !pip install transformers==2.6.0

import transformers
from transformers import GPT2Tokenizer, GPT2DoubleHeadsModel, DistilBertModel, DistilBertTokenizer, BertTokenizer, BertForTokenClassification
import numpy as np

import nltk
nltk.download('punkt')
from nltk import sent_tokenize
# %tensorflow_version 1.x
from keras.preprocessing.sequence import pad_sequences

from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors

import json
import matplotlib.pyplot as plt
import timeit
import torch
import textwrap
wrapper = textwrap.TextWrapper(width=70)
SEED = 1234
torch.manual_seed(SEED)

# %%
# change directory to where to models are kept
# make sure this dir contain sub dirs for fine-tuned BERT and GPT2 models

# %cd '/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021'
# Out:
# /content/drive/.shortcut-targets-by-id/17GW73wWB3WJJKQXTdFCaAZX60y4ccAfV/GPT2_Jan28_2021

# %% [markdown]
# ##A bit about the model
#
# 1. For sentence extraction, we can just use pre-trained distil-bert. this will speed things up even faster.
#
# 2. For token classification, we will be using BERT-based-cased
#
# 3. For the GPT2 model, we'll be using GPT2DoubleHead model. The "DoubleHead" of the model means the model is trained on both language modeling and multiple choice sentence prediction, and outputs 2 losses, the LM loss or language modeling loss, and MC loss or multiple choice loss.

# %%
#@title Choose Model Config and Weights

#@markdown Distil version is fine for this task
BERT_pretrained_weights = 'distilbert-base-uncased' #@param ["distilbert-base-uncased", "bert-base-uncased", "bert-base-cased"] {allow-input: true}

#@markdown for token classification we used 
BERTforTokenClassification_config_directory = '/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021' #@param {type:"string"}
token_label_files = '/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021/vocab.json' #@param {type:"string"}

GPT2_config_directory = '/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021' #@param {type:"string"}

print('which BERT pre-trained ? ',BERT_pretrained_weights)
print('where is BERT token classifier dir ? ',BERTforTokenClassification_config_directory)
print('where is GPT2 dir ? ',GPT2_config_directory)
# Out:
# which BERT pre-trained ?  distilbert-base-uncased
# where is BERT token classifier dir ?  /content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021
# where is GPT2 dir ?  /content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021

# %%
#@title Load models and tokenizers
#@markdown the models are big, these may take a few mins, read [here](https://huggingface.co/transformers/serialization.html) for more information

print('----loading pre-trained BERT----')
BERT_pretrained = DistilBertModel.from_pretrained(
                  BERT_pretrained_weights)
tokenizer_pretrained = DistilBertTokenizer.from_pretrained(
                  BERT_pretrained_weights)
print('----loading token labels----')
with open(token_label_files, 'r') as fp:
    POS2idx = json.load(fp)

POS_values = list(POS2idx.keys())
print('----loading BERT token classifier----')
BERT_token_classifier = BertForTokenClassification.from_pretrained(
                      BERTforTokenClassification_config_directory)
tokenizer_token_classifier = BertTokenizer.from_pretrained(
                      BERTforTokenClassification_config_directory)
#BERT_token_classifier.load_state_dict(torch.load(BERTforTokenClassification_finetuned_weights))
print('----loading GPT2 summary generator----')
tokenizer_GPT2 = GPT2Tokenizer.from_pretrained(
                  GPT2_config_directory)
special_tokens = {'bos_token':'<|startoftext|>','eos_token':'<|endoftext|>','pad_token':'<pad>','additional_special_tokens':['<|keyword|>','<|summarize|>']}
tokenizer_GPT2.add_special_tokens(special_tokens)
GPT2_generator = GPT2DoubleHeadsModel.from_pretrained(
                  GPT2_config_directory)
# Out:
# ----loading pre-trained BERT----
# ----loading token labels----
# ----loading BERT token classifier----
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-be2e7aeecc05> in <module>()
#      16                       BERTforTokenClassification_config_directory)
#      17 tokenizer_token_classifier = BertTokenizer.from_pretrained(
# ---> 18                       BERTforTokenClassification_config_directory)
#      19 #BERT_token_classifier.load_state_dict(torch.load(BERTforTokenClassification_finetuned_weights))
#      20 print('----loading GPT2 summary generator----')
#
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils.py in from_pretrained(cls, *inputs, **kwargs)
#     391
#     392         """
# --> 393         return cls._from_pretrained(*inputs, **kwargs)
#     394
#     395     @classmethod
#
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils.py in _from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#     494                     ", ".join(s3_models),
#     495                     pretrained_model_name_or_path,
# --> 496                     list(cls.vocab_files_names.values()),
#     497                 )
#     498             )
#
# OSError: Model name '/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021' was not found in tokenizers model name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). We assumed '/content/drive/MyDrive/Covid_Summary/GPT2_Jan28_2021' was a path, a model identifier, or url to a directory containing vocabulary files named ['vocab.txt'] but couldn't find such vocabulary files at this path or url.

# %%
#@title use GPU?

#@markdown check the box to indicate if GPU to be used for running any model?

use_GPU_BERT_pre_trained = False #@param {type:"boolean"}
use_GPU_BERT_token_classifier = False #@param {type:"boolean"}
use_GPU_GPT_generator = True #@param {type:"boolean"}

if torch.cuda.is_available():
  print('cuda is available')
  device = 'cuda'
  print('device is set to cuda')
if not torch.cuda.is_available():
  print('cuda is not available')
  device = 'cpu'
  print('device is set to cpu')
  use_GPU_BERT_pre_trained = False
  use_GPU_BERT_token_classifier = False
  use_GPU_GPT_generator = False

print(' ')
print('use GPU for pre-trained BERT?' ,use_GPU_BERT_pre_trained)
print('use GPU for BERT token classifier ?' ,use_GPU_BERT_token_classifier)
print('use GPU for GPT2?' ,use_GPU_GPT_generator)

# %%
#@title Main text file

#@markdown indicate the text file to be summarized
use_input_text = True

input_file = '/content/drive/MyDrive/Covid_Summary/covid.txt' #@param {type:"string"}
max_len = 500 #@param {type:"integer",max:512}

#@markdown or copy paste your input here and check the box
use_input_text = False #@param {type:"boolean"}
input_text = "'Two months after it was firstly reported, the novel coronavirus disease COVID-19 has already spread worldwide. However, the vast majority of reported infections have occurred in China. To assess the effect of early travel restrictions adopted by the health authorities in China, we have implemented an epidemic metapopulation model that is fed with mobility data corresponding to 2019 and 2020. This allows to compare two radically different scenarios, one with no travel restrictions and another in which mobility is reduced by a travel ban. Our findings indicate that i) travel restrictions are an effective measure in the short term, however, ii) they are ineffective when it comes to completely eliminate the disease. The latter is due to the impossibility of removing the risk of seeding the disease to other regions. Our study also highlights the importance of developing more realistic models of behavioral changes when a disease outbreak is unfolding.'" #@param {type:"string"}

if not use_input_text:
  # open the txt file that is included
  with open(input_file, 'r') as file:
    input_text = file.read().replace('\n', '')

# split text to sentences
paragraph_split = sent_tokenize(input_text)

print('input text has',len(paragraph_split) ,'sentences.')

print('tokenizing sentences')

input_tokens = []
for i in paragraph_split:
  input_tokens.append(tokenizer_pretrained.encode(i, 
                              add_special_tokens=True))
temp = []
for i in input_tokens:
  temp.append(len(i))
if np.max(temp) > max_len:
  raise ValueError('sentence longer than the max_len')
if np.max(temp) > 512:
  print('warning: sentence longer than 512')
  print('suggest to change max_len to 512, the remainder will be truncated')
input_ids = pad_sequences(input_tokens, 
                          maxlen=max_len, dtype="long", 
                          value=0, 
                          truncating="post", 
                          padding="post")

print('creating attention masks')

attention_masks = []
for sent in input_ids:
  att_mask = [int(token_id > 0) for token_id in sent]  # create a list of 0 and 1.
  attention_masks.append(att_mask)  # basically attention_masks is a list of list

input_ids = torch.tensor(input_ids)  
attention_mask = torch.tensor(attention_masks)

# %%
#@title Keyword extraction

list_to_pick = ['NN','NNP','NNPS','NNS','VBD','VB','VBZ','VBP']

tokenized_sentence = tokenizer_token_classifier.encode(
                      topic_answer_string)
input_ids2 = torch.tensor([tokenized_sentence[:510]])

if use_GPU_BERT_token_classifier:
  BERT_token_classifier = BERT_token_classifier.to(device)
  input_ids2 = input_ids2.to(device)

if not use_GPU_BERT_token_classifier:
  BERT_token_classifier = BERT_token_classifier.to('cpu')
  input_ids2 = input_ids2.to('cpu')

with torch.no_grad():
  output2 = BERT_token_classifier(input_ids2)
label_indices = np.argmax(output2[0].to('cpu').numpy(), axis=2)

list_keywords = []

tokens = tokenizer_token_classifier.convert_ids_to_tokens(
                        input_ids2.to('cpu').numpy()[0])
new_tokens, new_labels = [], []
for token, label_idx in zip(tokens, label_indices[0]):
    if token.startswith("##"):
        new_tokens[-1] = new_tokens[-1] + token[2:]
    else:
        new_labels.append(POS_values[label_idx])
        new_tokens.append(token)
for token, label in zip(new_tokens, new_labels):
    if label in list_to_pick:
      list_keywords.append(token)

print('finished keyword extraction ...')
print('the keywords are')

list_keywords = [i for i in list_keywords if i not in ['[CLS]','[SEP]','?','/','-','.','_','!','@','[',']']]
list_keywords

list_keywords_str = ' '.join(list_keywords)
wrapper.wrap(list_keywords_str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f45fa946b44e> in <module>()
#       3 list_to_pick = ['NN','NNP','NNPS','NNS','VBD','VB','VBZ','VBP']
#       4
# ----> 5 tokenized_sentence = tokenizer_token_classifier.encode(
#       6                       topic_answer_string)
#       7 input_ids2 = torch.tensor([tokenized_sentence[:510]])
#
# NameError: name 'tokenizer_token_classifier' is not defined
